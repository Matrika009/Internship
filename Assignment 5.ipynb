# %% [markdown]
# Q1: Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# Start a WebDriver session


def search(uinp):
    driver = webdriver.Chrome()
    driver.get("https://www.amazon.in/")
    time.sleep(2)
    search_box = driver.find_element(By.ID, "twotabsearchtextbox")
    search_box.send_keys(uinp)
    search_box.submit()
    time.sleep(3)


user_inp = input("Amazon Product to be searched: ")
search(user_inp)
# Out:
# Amazon Product to be searched: guitar

# %% [markdown]
# Q2: In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time
from selenium.common.exceptions import NoSuchElementException

# Start a WebDriver session and user input


user_inp = input("Amazon Product to be searched: ")
driver = webdriver.Chrome()
driver.get("https://www.amazon.in/")
time.sleep(2)
search_box = driver.find_element(By.ID, "twotabsearchtextbox")
search_box.send_keys(user_inp)
search_box.submit()
time.sleep(3)

start=0
end=2
data_brandn = []
data_p = []
data_pname = []
data_url = []
retrn =[]
exp_del=[]
stock=[]

for page in range(start,end):
 
  # Scrape url
    Brand_url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in Brand_url:
        title1=i.text
        data_url.append(i.get_attribute("href"))



    for i in data_url:
        driver.get(i)
        time.sleep(2)
        
        try:
            ret = driver.find_element(By.ID, "productTitle")
            data_brandn.append(ret.text)
        except NoSuchElementException:
            data_brandn.append("-")
            
        try:
            ret = driver.find_element(By.XPATH, "/html/body/div[2]/div/div[5]/div[3]/div[4]/div[13]/div/div/div[4]/div[1]/span[3]")
            data_p.append(ret.text)
        except NoSuchElementException:
            data_p.append("Exchange")
        
        try:
            ret = driver.find_element(By.XPATH, "/html/body/div[2]/div[1]/div/div[7]/div[1]/div[2]/div[2]/div/div/div[1]/div[14]/div[2]/div/div/div/div[2]/div/ol/li[3]/div/span/div[2]/span")
            retrn.append(ret.text)
        except NoSuchElementException:
            retrn.append("-")
        
        try:
            expd = driver.find_element(By.XPATH, "/html/body/div[2]/div/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[4]/div/div[3]/div[9]/div[1]/div/div/div/span/span")
            exp_del.append(expd.text)
        except NoSuchElementException:
            exp_del.append("-")
        
        try:
            stk = driver.find_element(By.ID, "availability")
            stock.append(stk.text)
        except NoSuchElementException:
            stock.append("-")
    
    try:
        next_page_button = driver.find_element(By.CSS_SELECTOR, '.s-pagination-next')
        next_page_button.click()
        time.sleep(3)
    except:
        break  # Break if there is no next page
        
df = pd.DataFrame({'Brand Name': data_brandn, 'Price': data_p,'Return/Exchange': retrn,'Expected Delivery': exp_del, 'Availability': stock,'Product URL': data_url})        
df.to_csv('list.csv', index=False)
# Out:
# Amazon Product to be searched: guitar

# %% [markdown]
# Q7: Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# Start a WebDriver session
driver = webdriver.Chrome()
driver.get("https://www.forbes.com/billionaires/")


# scrape the data for the first 10 jobs results you get.
rank_f = []
name_f = []
netw_f =[]
age_f=[]
citi_f=[]
sourc_f=[]
indust_f=[]

start=0
end=13
for page in range(start,end):
    Sno=driver.find_elements(By.XPATH, '//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
    for i in Sno:
        title=i.text
        rank_f.append(title)
    
    name=driver.find_elements(By.XPATH, '//div[@class="Table_dataCell__2QCve"]')
    for i in name:
        title=i.text
        name_f.append(title)
        name_ff=[]
    for x in range(0,len(name_f),4):
        name_ff.append(name_f[x])    

    netw=driver.find_elements(By.XPATH, '//div[@class="Table_netWorth___L4R5 Table_dataCell__2QCve"]')
    for i in netw:
        title=i.text
        netw_f.append(title)
    
    age_t =driver.find_elements(By.XPATH, '//div[@class="Table_dataCell__2QCve"]')
    for i in age_t:
        title=i.text
        age_f.append(title)
        age_ff=[]
    for x in range(1,len(age_f)+1,4):
        age_ff.append(age_f[x])
    
    citi_t =driver.find_elements(By.XPATH, '//div[@class="Table_dataCell__2QCve"]')
    for i in citi_t:
        title=i.text
        citi_f.append(title)
        citi_ff=[]
    for x in range(2,len(citi_f)+2,4):
        citi_ff.append(citi_f[x])
    

    source=driver.find_elements(By.XPATH, '//div[@class="Table_dataCell__2QCve"]')
    for i in source:
        title=i.text
        sourc_f.append(title)
        source_ff=[]
    for x in range(1,len(sourc_f)+1,4):
        source_ff.append(sourc_f[x])
        
    next_page_button = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[2]/div[2]/div[1]/button[2]/div/span[1]')
    next_page_button.click()
    time.sleep(3)
    
    
print(len(rank_f),len(name_ff),len(netw_f),len(age_ff),len(citi_ff),len(source_ff))

df = pd.DataFrame({'Rank': rank_f, 'Name': name_ff,'Networth': netw_f,'Age': age_ff, 'Citizenship': citi_ff,'Source': source_ff})        
df.to_csv('list1.csv', index=False)
# Out:
# 2600 2600 2600 2600 2600 2600

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# Start a WebDriver session
driver = webdriver.Chrome()
driver.get("https://www.forbes.com/billionaires/")


# scrape the data for the first 10 jobs results you get.
rank_f = []
name_f = []
netw_f =[]
age_f=[]
citi_f=[]
sourc_f=[]
indust_f=[]

start=0
end=13
for page in range(start,end):
    Sno=driver.find_elements(By.XPATH, '//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
    for i in Sno:
        title=i.text
        rank_f.append(title)
    
    name=driver.find_elements(By.XPATH, '//div[@class="Table_dataCell__2QCve"]')
    for i in name:
        title=i.text
        name_f.append(title)
        name_ff=[]
    for x in range(0,len(name_f),4):
        name_ff.append(name_f[x])    

    netw=driver.find_elements(By.XPATH, '//div[@class="Table_netWorth___L4R5 Table_dataCell__2QCve"]')
    for i in netw:
        title=i.text
        netw_f.append(title)
    
    age_t =driver.find_elements(By.XPATH, '//div[@class="Table_dataCell__2QCve"]')
    for i in age_t:
        title=i.text
        age_f.append(title)
        age_ff=[]
    for x in range(1,len(age_f)+1,4):
        age_ff.append(age_f[x])
    
    citi_t =driver.find_elements(By.XPATH, '//div[@class="Table_dataCell__2QCve"]')
    for i in citi_t:
        title=i.text
        citi_f.append(title)
        citi_ff=[]
    for x in range(2,len(citi_f)+2,4):
        citi_ff.append(citi_f[x])
    

    source=driver.find_elements(By.XPATH, '//div[@class="Table_dataCell__2QCve"]')
    for i in source:
        title=i.text
        sourc_f.append(title)
        source_ff=[]
    for x in range(3,len(sourc_f)+3,4):
        source_ff.append(sourc_f[x])
        
    next_page_button = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[2]/div[2]/div[1]/button[2]/div/span[1]')
    next_page_button.click()
    time.sleep(3)
    
    
df = pd.DataFrame({'Rank': rank_f, 'Name': name_ff,'Networth': netw_f,'Age': age_ff, 'Citizenship': citi_ff,'Source': source_ff})        
df.to_csv('list1.csv', index=False)

# %% [markdown]
# Q4: Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import re

def extract_product_details(product_string):
    # Use regular expressions to extract brand, model, color, and storage information
    match = re.search(r'([^\d]+) (\w+) \(([^,]+), (\d+ GB)\)', product_string)

    # Check if a match was found
    if match:
        brand = match.group(1).strip()
        model = match.group(2).strip()
        color = match.group(3).strip()
        storage = match.group(4).strip()
        return brand, model, color, storage
    else:
        return None, None, None, None
    
def extract_model_name(product_string):
    # Use regular expressions to extract the model name
    match = re.search(r'([^\d]+) (\w+)', product_string)

    # Check if a match was found
    if match:
        brand = match.group(1).strip()
        model = match.group(2).strip()
        return f"{brand} {model}"
    else:
        return None  


# Start a Chrome webdriver session
driver = webdriver.Chrome()

# Open  website
driver.get("https://www.flipkart.com/")
time.sleep(5)
search1=driver.find_element(By.XPATH,"/html/body/div[3]/div/span")
search1.click()


#Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
search2=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/div/input")
search2.send_keys("Smartphone")
search3=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/button")
search3.click()
time.sleep(5)

SP_Name_f=[]
SP_Price_f=[]
SP_others=[]
SP_ROM_f=[]
SP_Camera_f=[]
SP_display_f=[]
SP_battery_f=[]

sp=driver.find_elements(By.XPATH, '//div[@class="_4rR01T"]')
for i in sp:
    title=i.text
    SP_Name_f.append(title)
brands = []
models = []
modelnames=[]
colors = []
storages = []

# Extract details for each product string
for product_string in SP_Name_f:
    brand, model, color, storage = extract_product_details(product_string)
    colors.append(color)
    storages.append(storage)

print(colors,storages)
for x in SP_Name_f:
    model_name = extract_model_name(x)
    if model_name:
        modelnames.append(model_name)

print(modelnames)
    


sp=driver.find_elements(By.XPATH, '//div[@class="_30jeq3 _1_WHN1"]')
for i in sp:
    title=i.text
    SP_Price_f.append(title)
print(SP_Price_f)

sp=driver.find_elements(By.XPATH, '//li[@class="rgWa7D"]')
x=0
print(sp)
for i in sp:
    title=i.text
    print(title)
 #   SP_others.append(title)
#print(SP_others)
# Out:
# ['Astral Black', 'Horizon Blue', 'Blue', 'Starlight', None, 'Midnight', 'Royal Blue', 'Horizon Blue', None, 'Opal Green', 'Yellow', 'Astral Black', 'Aurora Gold', 'Aurora Gold', 'Marine Blue', 'Marine Blue', 'Yellow', 'Glimmer Black', 'Glimmer Black', None, 'Cool Blue', 'Marine Blue', 'Aurora Gold', 'Glimmer Black'] ['256 GB', '128 GB', '128 GB', '128 GB', None, '128 GB', '64 GB', '256 GB', None, '64 GB', '256 GB', '128 GB', '128 GB', '128 GB', '128 GB', '128 GB', '128 GB', '128 GB', '128 GB', None, '128 GB', '128 GB', '128 GB', '128 GB']
# ['POCO X5', 'POCO X5', 'APPLE iPhone 14', 'APPLE iPhone 14', 'APPLE iPhone 14', 'APPLE iPhone 14', 'POCO C51', 'POCO X5', 'APPLE iPhone 14', 'SAMSUNG Galaxy F04', 'POCO X5', 'POCO X5', 'vivo T2x', 'vivo T2x', 'vivo T2x', 'vivo T2x', 'POCO X5', 'vivo T2x', 'vivo T2x', 'APPLE iPhone 14', 'POCO C55', 'vivo T2x', 'vivo T2x', 'vivo T2x']
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import re

def extract_product_details(product_string):
    # Use regular expressions to extract brand, model, color, and storage information
    match = re.search(r'([^\d]+) (\w+) \(([^,]+), (\d+ GB)\)', product_string)

    # Check if a match was found
    if match:
        brand = match.group(1).strip()
        model = match.group(2).strip()
        color = match.group(3).strip()
        storage = match.group(4).strip()
        return brand, model, color, storage
    else:
        return None, None, None, None
    
def extract_model_name(product_string):
    # Use regular expressions to extract the model name
    match = re.search(r'([^\d]+) (\w+)', product_string)

    # Check if a match was found
    if match:
        brand = match.group(1).strip()
        model = match.group(2).strip()
        return f"{brand} {model}"
    else:
        return None  


# Start a Chrome webdriver session
driver = webdriver.Chrome()

# Open  website
driver.get("https://www.flipkart.com/")
time.sleep(5)
search1=driver.find_element(By.XPATH,"/html/body/div[3]/div/span")
search1.click()


#Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
search2=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/div/input")
search2.send_keys("Smartphone")
search3=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/button")
search3.click()
time.sleep(5)

SP_Name_f=[]
SP_Price_f=[]
sp=[]
SP_ROM_f=[]
SP_Camera_f=[]
SP_display_f=[]
SP_battery_f=[]



Sno=driver.find_elements(By.XPATH, '//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
for i in Sno:
    title=i.text
    rank_f.append(title)


sp_oth=driver.find_elements(By.XPATH, '//li[@class="rgWa7D"]')
for i in sp_oth:
    title=i.text
    sp.append(title)

x=0
for y in sp:
    if "RAM" in sp[x]:
        SP_ROM_f.append(sp[x])
        x=x+1
    else:
        SP_ROM_f.append("-")
        x=x+1
    print(SP_ROM_f,x)
        
    
    if "inch" in sp[x]:
        SP_display_f.append(sp[x])
        x=x+1
    else:
        SP_display_f.append("-")
        x=x+1
    print(SP_display_f,x)    
    
    if "Camera" in sp[x]:
        SP_Camera_f.append(sp[x])
        x=x+1
    else:
        SP_Camera_f.append("-")
        x=x+1
    print(SP_Camera_f,x)    
    
    if "Battery" in sp[x]:
        SP_battery_f.append(sp[x])
        x=x+1
    else:
        SP_battery_f.append("-")
        x=x+1
    
    if "Processor" in sp[x]:
        x=x+1
    else:
        x=x+1
    if "Warranty" in sp[x]:
        x=x+1
    else:
        x=x+1
# Out:
# ['8 GB RAM | 256 GB ROM'] 1
# ['16.94 cm (6.67 inch) Full HD+ Display'] 2
# ['108MP + 8MP + 2MP | 16MP Front Camera'] 3
# ['8 GB RAM | 256 GB ROM', '6 GB RAM | 128 GB ROM'] 7
# ['16.94 cm (6.67 inch) Full HD+ Display', '16.94 cm (6.67 inch) Full HD+ Display'] 8
# ['108MP + 8MP + 2MP | 16MP Front Camera', '108MP + 8MP + 2MP | 16MP Front Camera'] 9
# ['8 GB RAM | 256 GB ROM', '6 GB RAM | 128 GB ROM', '-'] 13
# ['16.94 cm (6.67 inch) Full HD+ Display', '16.94 cm (6.67 inch) Full HD+ Display', '15.49 cm (6.1 inch) Super Retina XDR Display'] 14
# ['108MP + 8MP + 2MP | 16MP Front Camera', '108MP + 8MP + 2MP | 16MP Front Camera', '12MP + 12MP | 12MP Front Camera'] 15
# ['8 GB RAM | 256 GB ROM', '6 GB RAM | 128 GB ROM', '-', '-'] 19
# ['16.94 cm (6.67 inch) Full HD+ Display', '16.94 cm (6.67 inch) Full HD+ Display', '15.49 cm (6.1 inch) Super Retina XDR Display', '-'] 20
# ...
